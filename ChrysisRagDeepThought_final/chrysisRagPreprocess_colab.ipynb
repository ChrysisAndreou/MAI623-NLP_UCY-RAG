# %% [markdown]
# # chrysisRagPrerocess

# %% [markdown]
# ## Instructions

# %% [markdown]
# Open the chrysisRagPrerocess_colab notebook and follow its instructions.
#
# Load the chrysisRagPreprocess.zip folder. Run the code in the specified order.

# %% [markdown]
# ## Unzip chrysisRagPreprocess folder

# %%
# !unzip chrysisRagPreprocess.zip -d /content/

# %% [markdown]
# ## Install requirements

# %%
# !pip install -r requirements.txt

# %% [markdown]
# ## Convert links to html (advice to skip exexuting the code)

# %% [markdown]
# Skip executing the code links to HTML (since the HTML is already provided). If you want to execute the code, you will need BrightData credentials.

# %%
# !python 01_linksToHtml.py

# %% [markdown]
# ## Convert html files to markdown

# %%
# !python 02_htmlToMD.py

# %% [markdown]
# ## Clean markdown files

# %%
# !python 03_clean_md.py

# %% [markdown]
# ## Keep long files

# %%
# !python 04_long_files.py
